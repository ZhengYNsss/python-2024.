# %%
#第九章 类
#创建 Dog 类
class Dog: 
 """一次模拟小狗的简单尝试""" 
 
def __init__(self, name, age): 
 """初始化属性 name 和 age""" 
 self.name = name 
 self.age = age 
 
def sit(self): 
 """模拟小狗收到命令时坐下""" 
 print(f"{self.name} is now sitting.") 
 
 def roll_over(self): 
  """模拟小狗收到命令时打滚""" 
 print(f"{self.name} rolled over!")
 #9.1.2 根据类创建实例
class Dog: 
  --snip--  
 
my_dog = Dog('Willie', 6) 
 
print(f"My dog's name is {my_dog.name}.") 
print(f"My dog is {my_dog.age} years old.")
#03创建多个实例
class Dog: 
 --snip-- 
 
my_dog = Dog('Willie', 6) 
your_dog = Dog('Lucy', 3) 
 
print(f"My dog's name is {my_dog.name}.")
print(f"My dog is {my_dog.age} years old.")
my_dog.sit() 
 
print(f"\nYour dog's name is {your_dog.name}.")
print(f"Your dog is {your_dog.age} years old.")
your_dog.sit()
#练习
#9.1
class Restaurant:  
    def __init__(self, restaurant_name, cuisine_type):  
        self.restaurant_name = restaurant_name  
        self.cuisine_type = cuisine_type  
  
    def describe_restaurant(self):  
        print(f"The {self.restaurant_name} restaurant specializes in {self.cuisine_type} cuisine.")  
  
    def open_restaurant(self):  
        print(f"{self.restaurant_name} is open for business.")  
  
# 创建一个餐馆实例  
restaurant = Restaurant("Italian Café", "Italian")  
  
# 打印两个属性  
print(f"Restaurant Name: {restaurant.restaurant_name}")  
print(f"Cuisine Type: {restaurant.cuisine_type}")  
  
# 调用两个方法  
restaurant.describe_restaurant()  
restaurant.open_restaurant()
#9.2
class Restaurant:  
    def __init__(self, restaurant_name, cuisine_type):  
        self.restaurant_name = restaurant_name  
        self.cuisine_type = cuisine_type  
  
    def describe_restaurant(self):  
        print(f"The {self.restaurant_name} restaurant specializes in {self.cuisine_type} cuisine.")  
  
    def open_restaurant(self):  
        print(f"{self.restaurant_name} is open for business.")  
# 创建三个餐馆实例  #9.1
class Restaurant:  
    def __init__(self, restaurant_name, cuisine_type):  
        self.restaurant_name = restaurant_name  
        self.cuisine_type = cuisine_type  
  
    def describe_restaurant(self):  
        print(f"The {self.restaurant_name} restaurant specializes in {self.cuisine_type} cuisine.")  
  
    def open_restaurant(self):  
        print(f"{self.restaurant_name} is open for business.")  
  
# 创建一个餐馆实例  
restaurant = Restaurant("Italian Café", "Italian")  
  
# 打印两个属性  
print(f"Restaurant Name: {restaurant.restaurant_name}")  
print(f"Cuisine Type: {restaurant.cuisine_type}")  
  
# 调用两个方法  
restaurant.describe_restaurant()  
restaurant.open_restaurant()
restaurant1 = Restaurant("Thai Delight", "Thai")  
restaurant2 = Restaurant("Pizza Palace", "Pizza")  
restaurant3 = Restaurant("Chinese Garden", "Chinese")  
# 对每个实例调用describe_restaurant()方法  
restaurant1.describe_restaurant()  
restaurant2.describe_restaurant()  
restaurant3.describe_restaurant()
#9.3
class User:  
    def __init__(self, first_name, last_name, age, email):  
        self.first_name = first_name  
        self.last_name = last_name  
        self.age = age  
        self.email = email  
  
    def describe_user(self):  
        print(f"User: {self.first_name} {self.last_name}, Age: {self.age}, Email: {self.email}")  
  
    def greet_user(self):  
        print(f"Hello, {self.first_name}! Welcome to our platform.")  
  
# 创建多个用户实例  
user1 = User("John", "Doe", 30, "john.doe@example.com")  
user2 = User("Jane", "Smith", 25, "jane.smith@example.com")  
user3 = User("Mike", "Johnson", 40, "mike.johnson@example.com")  
  
# 对每个实例调用上述两个方法  
user1.describe_user()  
user1.greet_user()  
#9.2 使用类和实例
#9.2.1Car类
class Car: 
 """一次模拟汽车的简单尝试""" 
 
def __init__(self, make, model, year): 
 """初始化描述汽车的属性""" 
 self.make = make 
 self.model = model 
 self.year = year 
 
def get_descriptive_name(self): 
 """返回格式规范的描述性信息""" 
 long_name = f"{self.year} {self.make} {self.model}" 
 return long_name.title() 
 
my_new_car = Car('audi', 'a4', 2024) 
print(my_new_car.get_descriptive_name())
#9.2.2 给属性指定默认值
class Car: 
 
 def __init__(self, make, model, year): 
  """初始化描述汽车的属性""" 
 self.make = make 
 self.model = model 
 self.year = year 
 self.odometer_reading = 0 
 
def get_descriptive_name(self): 
 --snip-- 
 
def read_odometer(self): 
 """打印一条指出汽车行驶里程的消息""" 
 print(f"This car has {self.odometer_reading} miles on it.") 
 
 my_new_car = Car('audi', 'a4', 2024) 
 print(my_new_car.get_descriptive_name()) 
 my_new_car.read_odometer()
#9.2.3 修改属性的值
#01. 直接修改属性的值
class Car: 
    --snip--     
 
my_new_car = Car('audi', 'a4', 2024) 
print(my_new_car.get_descriptive_name()) 
 
my_new_car.odometer_reading = 23 
my_new_car.read_odometer() 
#02. 通过方法修改属性的值
class Car: 
 --snip-- 
 
 def update_odometer(self, mileage): 
  """将里程表读数设置为指定的值""" 
 self.odometer_reading = mileage 
 
 my_new_car = Car('audi', 'a4', 2024) 
 print(my_new_car.get_descriptive_name()) 
 
my_new_car.update_odometer(23) 
m
_new_car.read_odometer()

class Car: 
 --snip-- 
 
 def update_odometer(self, mileage): 
  """ 
  将里程表读数设置为指定的值 
  禁止将里程表读数往回调 
  """ 
 if mileage >= self.odometer_reading: 
  self.odometer_reading = mileage 
 else: 
  print("You can't roll back an odometer!")
#03. 通过方法让属性的值递增
class Car: 
 --snip-- 
 
 def update_odometer(self, mileage): 
  --snip-- 
 
 def increment_odometer(self, miles): 
  """让里程表读数增加指定的量""" 
  self.odometer_reading += miles 
 
my_used_car = Car('subaru', 'outback', 2019) 
print(my_used_car.get_descriptive_name())  
my_used_car.update_odometer(23_500) 
my_used_car.read_odometer() 
 
my_used_car.increment_odometer(100) 
my_used_car.read_odometer()
#练习
#9.4就餐人数
class Restaurant:    
    def __init__(self, restaurant_name, cuisine_type):    
        self.restaurant_name = restaurant_name    
        self.cuisine_type = cuisine_type    
        self.number_served = 0  # 添加 number_served 属性并设置默认值为 0  
    
    def describe_restaurant(self):    
        print(f"The {self.restaurant_name} restaurant specializes in {self.cuisine_type} cuisine.")    
    
    def open_restaurant(self):    
        print(f"{self.restaurant_name} is open for business.")    
    
    def print_number_served(self):  # 添加一个方法来打印就餐人数  
        print(f"Number of people served: {self.number_served}")  
  
    def set_number_served(self, num):  # 添加一个方法来设置就餐人数  
        self.number_served = num  
  
    def increment_number_served(self, num):  # 添加一个方法来增加就餐人数  
        self.number_served += num  
  
# 创建一个餐馆实例    
restaurant = Restaurant("Italian Café", "Italian")    
  
# 打印餐馆名称和菜系类型  
print(f"Restaurant Name: {restaurant.restaurant_name}")    
print(f"Cuisine Type: {restaurant.cuisine_type}")    
  
# 打印当前就餐人数  
restaurant.print_number_served()  
  
# 设置就餐人数为 100  
restaurant.set_number_served(100)  
  
# 再次打印就餐人数  
restaurant.print_number_served()  
  
# 假设餐馆每天可能接待 50 人，增加这个数字到就餐人数中  
restaurant.increment_number_served(50)  
  
# 再次打印就餐人数  
restaurant.print_number_served()
#9.5class User:    
def __init__(self, first_name, last_name, age, email):    
        self.first_name = first_name    
        self.last_name = last_name    
        self.age = age    
        self.email = email    
        self.login_attempts = 0  # 添加 login_attempts 属性并设置默认值为 0  
    
def describe_user(self):    
        print(f"User: {self.first_name} {self.last_name}, Age: {self.age}, Email: {self.email}")    
    
def greet_user(self):    
        print(f"Hello, {self.first_name}! Welcome to our platform.")    
    
def increment_login_attempts(self):  # 添加 increment_login_attempts 方法  
        self.login_attempts += 1  
    
def reset_login_attempts(self):  # 添加 reset_login_attempts 方法  
        self.login_attempts = 0  
  
# 创建一个用户实例    
user1 = User("John", "Doe", 30, "john.doe@example.com")    
  
# 调用 increment_login_attempts() 方法多次  
user1.increment_login_attempts()  
user1.increment_login_attempts()  
user1.increment_login_attempts()  
  
# 打印 login_attempts 的值  
print(f"Login attempts: {user1.login_attempts}")  
  
# 调用 reset_login_attempts() 方法  
user1.reset_login_attempts()  
  
# 再次打印 login_attempts 的值  
print(f"Login attempts after reset: {user1.login_attempts}")
#9.3 继承
#9.3.1 子类的 __init__() 方法
class Car: 
 """一次模拟汽车的简单尝试""" 
 
 def __init__(self, make, model, year): 
  """初始化描述汽车的属性""" 
  self.make = make 
  self.model = model 
  self.year = year 
  self.odometer_reading = 0 
 
 def get_descriptive_name(self): 
  """返回格式规范的描述性名称""" 
  long_name = f"{self.year} {self.make} {self.model}" 
  return long_name.title() 
 
 def read_odometer(self): 
  """打印一个句子，指出汽车的行驶里程""" 
  print(f"This car has {self.odometer_reading} miles on it.")  
 def update_odometer(self, mileage): 
  """将里程表读数设置为给定的值""" 
  if mileage >= self.odometer_reading: 
   self.odometer_reading = mileage 
  else: 
   print("You can't roll back an odometer!") 
 
 def increment_odometer(self, miles): 
  """让里程表读数增加给定的量""" 
  self.odometer_reading += miles 
 
class ElectricCar(Car): 
 """电动汽车的独特之处""" 
 
 def __init__(self, make, model, year): 
   """初始化父类的属性""" 
   super().__init__(make, model, year) 
 
 
my_leaf = ElectricCar('nissan', 'leaf', 2024) 
print(my_leaf.get_descriptive_name())
#9.3.2 给子类定义属性和方法
lass 
Car:
--snip-- 
  
class ElectricCar(Car): 
  """电动汽车的独特之处""" 
 
  def __init__(self, make, model, year): 
   """ 
   先初始化父类的属性，再初始化电动汽车特有的属性 
   """ 
   super().__init__(make, model, year) 
   self.battery_size = 40 
 
  def describe_battery(self): 
   """打印一条描述电池容量的消息""" 
   print(f"This car has a {self.battery_size}-kWh battery.") 
 
my_leaf = ElectricCar('nissan', 'leaf', 2024) 
print(my_leaf.get_descriptive_name()) 
my_leaf.describe_battery()
#9.3.3 重写父类中的方法
class ElectricCar(Car): 
 --snip-- 
 
 def fill_gas_tank(self): 
  """电动汽车没有油箱""" 
  print("This car doesn't have a gas tank!")
#9.3.4 将实例用作属性
class Car: 
 --snip-- 
 
class Battery: 
 """一次模拟电动汽车电池的简单尝试""" 
 
 def __init__(self, battery_size=40): 
  """初始化电池的属性""" 
  self.battery_size = battery_size 
 
 def describe_battery(self): 
  """打印一条描述电池容量的消息""" 
  print(f"This car has a {self.battery_size}-kWh battery.") 
 
 
class ElectricCar(Car): 
 """电动汽车的独特之处""" 
 
 def __init__(self, make, model, year): 
  """ 
  先初始化父类的属性，再初始化电动汽车特有的属性 
  """ 
  super().__init__(make, model, year) 
  self.battery = Battery() 
 
 my_leaf = ElectricCar('nissan', 'leaf', 2024) 
 print(my_leaf.get_descriptive_name()) 
 my_leaf.battery.describe_battery()

class Car: 
 --snip-- 
 
class Battery: 
 --snip-- 
 
 def get_range(self): 
  """打印一条消息，指出电池的续航里程""" 
  if self.battery_size == 40: 
   range = 150 
  elif self.battery_size == 65: 
   range = 225 
 
  print(f"This car can go about {range} miles on a full charge.") 
 
class ElectricCar(Car): 
  --snip-- 
 
my_leaf = ElectricCar('nissan', 'leaf', 2024) 
print(my_leaf.get_descriptive_name())  my_leaf.battery.describe_battery() 
my_leaf.battery.get_range()
#练习
#9.6冰淇淋小店
class Restaurant:  
    def __init__(self, restaurant_name, cuisine_type):  
        self.restaurant_name = restaurant_name  
        self.cuisine_type = cuisine_type  
  
    def describe_restaurant(self):  
        print(f"The {self.restaurant_name} restaurant specializes in {self.cuisine_type} cuisine.")  
  
    def open_restaurant(self):  
        print(f"{self.restaurant_name} is open for business.")  
 
def __init__(self, restaurant_name, cuisine_type):  
        self.restaurant_name = restaurant_name  
        self.cuisine_type = cuisine_type  
  
class IceCreamStand(Restaurant):  
    def __init__(self, restaurant_name, cuisine_type, flavors):  
        super().__init__(restaurant_name, cuisine_type)  
        self.flavors = flavors  
  
    def show_flavors(self):  
        print(f"The {self.restaurant_name} serves the following flavors:")  
        for flavor in self.flavors:  
            print(f"- {flavor}")  
  
# 创建一个IceCreamStand实例并调用show_flavors方法  
ice_cream_shop = IceCreamStand("Sweet Dreams", "Ice Cream", ["Chocolate", "Vanilla", "Strawberry", "Mint"])  
ice_cream_shop.show_flavors() 
#9.7
class User:  
    def __init__(self, first_name, last_name, age, email):  
        self.first_name = first_name  
        self.last_name = last_name  
        self.age = age  
        self.email = email  
  
    def describe_user(self):  
        print(f"User: {self.first_name} {self.last_name}, Age: {self.age}, Email: {self.email}")  
  
    def greet_user(self):  
        print(f"Hello, {self.first_name}! Welcome to our platform.")  
    def __init__(self, first_name, last_name):  
        self.first_name = first_name  
        self.last_name = last_name  
  
class Admin(User):  
    def __init__(self, first_name, last_name, privileges):  
        super().__init__(first_name, last_name)  
        self.privileges = privileges  
  
    def show_privileges(self):  
        print(f"The admin {self.first_name} {self.last_name} has the following privileges:")  
        for privilege in self.privileges:  
            print(f"- {privilege}")  
  
# 创建一个Admin实例并调用show_privileges方法  
admin_user = Admin("Alice", "Wonderland", ["can add post", "can delete post", "can ban user"])  
admin_user.show_privileges()
#9.8权限
class Privileges:  
    def __init__(self, privileges_list):  
        self.privileges = privileges_list  
  
    def show_privileges(self):  
        print("Privileges:")  
        for privilege in self.privileges:  
            print(f"- {privilege}")  
  
class Admin(User):  
    def __init__(self, first_name, last_name, privileges):  
        super().__init__(first_name, last_name)  
        self.privileges = Privileges(privileges)  
  
    def show_privileges(self):  
        self.privileges.show_privileges()  
  
# 创建一个Admin实例并调用show_privileges方法  
admin_user = Admin("Bob", "Smith", ["can add post", "can delete post", "can ban user"])  
admin_user.show_privileges()
#9.9
#完整car.py
 
class Car: 
 """一次模拟汽车的简单尝试""" 
 
 def __init__(self, make, model, year): 
  """初始化描述汽车的属性""" 
  self.make = make 
  self.model = model 
  self.year = year 
  self.odometer_reading = 0 
 
 def get_descriptive_name(self): 
  """返回格式规范的描述性名称""" 
  long_name = f"{self.year} {self.make} {self.model}" 
  return long_name.title() 
 
 def read_odometer(self): 
  """打印一个句子，指出汽车的行驶里程""" 
  print(f"This car has {self.odometer_reading} miles on it.")  
 def update_odometer(self, mileage): 
  """将里程表读数设置为给定的值""" 
  if mileage >= self.odometer_reading: 
   self.odometer_reading = mileage 
  else: 
   print("You can't roll back an odometer!") 
 
 def increment_odometer(self, miles): 
  """让里程表读数增加给定的量""" 
  self.odometer_reading += miles 

 
 class Battery:  
    """一次模拟电动汽车电池的简单尝试"""  
  
    def __init__(self, battery_size=70): 
        """初始化电池的属性"""  
        self.battery_size = battery_size  
  
    def describe_battery(self):  
        """打印一条描述电池容量的消息"""  
        print(f"This car has a {self.battery_size}-kWh battery.")  
  
    def upgrade_battery(self):  
        """如果电池容量不是65kWh，则将其设置为65kWh"""  
        if self.battery_size != 65:  
            self.battery_size = 65  
            print("Battery upgraded to 65kWh.")  
  
    def get_range(self):  
        """根据电池容量打印电池的续航里程"""  
        if self.battery_size == 40:  
            range_ = 150  
        elif self.battery_size == 65:  
            range_ = 225  
        else:  
            range_ = "unknown"  
        print(f"This car can go about {range_} miles on a full charge.")  
  
class ElectricCar(Car):  
    # ... 
  
    def __init__(self, make, model, year):  
        """   
        先初始化父类的属性，再初始化电动汽车特有的属性   
        """  
        super().__init__(make, model, year)  
        self.battery = Battery()  
  
# 创建一辆电池容量为默认值的电动汽车  
my_leaf = ElectricCar('nissan', 'leaf', 2024)  
  
# 调用方法打印描述性名称和电池详情  
print(my_leaf.get_descriptive_name())  
my_leaf.battery.describe_battery()  
  
# 调用get_range()查看原始续航里程  
print("Before upgrade:")  
my_leaf.battery.get_range()  
  
# 升级电池  
my_leaf.battery.upgrade_battery()  
  
# 再次调用get_range()查看升级后的续航里程  
print("After upgrade:")  
my_leaf.battery.get_range()
#9.4导入类
#9.4.1导入单个类
from car import Car 
 
my_new_car = Car('audi', 'a4', 2024) 
print(my_new_car.get_descriptive_name()) 
 
my_new_car.odometer_reading = 23 
my_new_car.read_odometer()
#9.4.2 在一个模块中存储多个类
#my_cars.py
from car import Car 
from electric_car import ElectricCar 
 
my_mustang = Car('ford', 'mustang', 2024) 
print(my_mustang.get_descriptive_name()) 
 
my_leaf = ElectricCar('nissan', 'leaf', 2024) 
print(my_leaf.get_descriptive_name())
#9.4.7 使用别名
from electric_car import ElectricCar as EC
my_leaf = EC('nissan', 'leaf', 2024)
import electric_car as ec
my_leaf = ec.ElectricCar('nissan', 'leaf', 2024)
#9.5 Python 标准库
from random import randint 
randint(1, 6) 
 
from random import choice 
players = ['charles', 'martina', 'michael', 'florence', 'eli'] 
first_up = choice(players) 
first_up 

#练习
#9.10
from restaurant import Restaurant  
  
# 创建一个 Restaurant 实例  
my_restaurant = Restaurant("Pizza Hut", "Italian")  
  
# 调用方法并打印结果  
print(my_restaurant.describe_restaurant())
#9.11
from user_admin import Admin  
  
# 创建一个 Admin 实例  
admin = Admin("Alice", "Smith", email="alice@example.com")  
  
# 调用 show_privileges() 方法  
admin.show_privileges()


from admin import Admin  
  
# 创建一个 Admin 实例  
admin = Admin("Bob", "Johnson", email="bob@example.com")  
  
# 调用 show_privileges() 方法  
admin.show_privileges()
#9.13
import random  
  
class Die:  
    def __init__(self, sides=6):  
        self.sides = sides  
  
    def roll_die(self):  
        return random.randint(1, self.sides)  
  
# 创建一个6面的骰子并掷10次  
d6 = Die()  
for i in range(10):  
    print(f"You rolled: {d6.roll_die()}")  
  
# 创建一个10面的骰子并掷10次  
d10 = Die(10)  
for i in range(10):  
    print(f"You rolled: {d10.roll_die()}")  
  
# 创建一个20面的骰子并掷10次  
d20 = Die(20)  
for i in range(10):  
    print(f"You rolled: {d20.roll_die()}")
#练习 9.14：彩票
import random  
  
# 创建一个包含10个数和5个字母的列表  
lottery_items = list(range(1, 11)) + ['A', 'B', 'C', 'D', 'E']  
  
# 随机选择4个元素  
winning_numbers = random.sample(lottery_items, 4)  
  
# 打印中奖号码  
print(f"The winning numbers are: {winning_numbers}")  
print(f"If your ticket matches these {len(winning_numbers)} numbers or letters, you win the jackpot!")
#9.15
import random  
  
# 创建一个包含10个数和5个字母的列表  
lottery_items = list(range(1, 11)) + ['A', 'B', 'C', 'D', 'E']  
  
# 随机选择4个元素  
winning_numbers = random.sample(lottery_items, 4)  
  
# 打印中奖号码  
print(f"The winning numbers are: {winning_numbers}")  
print(f"If your ticket matches these {len(winning_numbers)} numbers or letters, you win the jackpot!")
#9.16
import random  
  
# 创建一个包含各种选项的列表  
options = ['Apple', 'Banana', 'Cherry', 'Date', 'Elderberry']  
  
# 随机选择一个元素  
chosen_option = random.choice(options)  
  
# 打印被选择的元素  
print(f"You have chosen: {chosen_option}")
# Out:
#   Cell In[1], line 20
#     --snip--
#               ^
# SyntaxError: invalid syntax
